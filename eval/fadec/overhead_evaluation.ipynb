# %%
from extern_funcs_cython import interpolate, ln, lstm_state_calculator
from fusion import fusion_quantize_cython, prep_cython
from keyframe_buffer import KeyframeBuffer
from pynq import Overlay, allocate
import numpy as np
import math
import time
import nngen_ctrl as ng

# %%
params = np.load("./flattened_params/flattened_params.npz")['arr_0']
data_npz = np.load("data_7scenes/chess-seq-01.npz")

# %%
output_files = ['feature_half',
                'cell_state',
                'hidden_state',
                'depth_org']
cell_state_idx = output_files.index('cell_state')
output_aligned_shapes = [(1, 32, 48, 32),
                         (1, 2, 3, 512),
                         (1, 2, 3, 512),
                         (1, 64, 96, 8)]

input_files = ['reference_image',
               'hidden_state',
               'cell_state']
hidden_state_idx = len(output_files) + input_files.index('hidden_state')
input_aligned_shapes = [(1, 64, 96, 8),
                        (1, 2, 3, 512),
                        (1, 2, 3, 512)]

# %%
chunk_size = 64
def get_end_addr(addr, memory_size):
    return int(math.ceil((addr + memory_size) / chunk_size)) * chunk_size

def shape2size(shape):
    size = 1
    for s in shape:
        size *= s
    return size

# %%
axi_datawidth = 128
act_bit = 16
num_align_words = axi_datawidth // act_bit

output_offset = 0
addrs = [output_offset]
for output_aligned_shape in output_aligned_shapes:
    addrs.append(get_end_addr(addrs[-1], shape2size(output_aligned_shape) * (act_bit // 8)))

input_offset = addrs[-1]
for input_aligned_shape in input_aligned_shapes:
    addrs.append(get_end_addr(addrs[-1], shape2size(input_aligned_shape) * (act_bit // 8)))
cell_state_offset = addrs[-2] # change output cell_state addr to input addr
addrs[cell_state_idx] = cell_state_offset
hidden_state_offset = 176869824
addrs[hidden_state_idx] = hidden_state_offset
param_offset = addrs[-1]
print(output_offset, input_offset, param_offset)
print(addrs)
# Out:
# 0 208896 319488
# [0, 313344, 104448, 110592, 208896, 176869824, 313344, 319488]

# %%
bitfile = 'design_1.bit'
ipname = 'dvmvs_0'

overlay = Overlay(bitfile)
ip = ng.nngen_core(overlay, ipname)

# %%
memory_size = 1024 * 1024 * 192
buf = allocate(shape=(memory_size,), dtype=np.uint8)
buf[param_offset:param_offset + params.size] = params.view(np.int8)

# %%
ip.set_global_buffer(buf)
ip.write_buffer_address(cell_state_idx, cell_state_offset)
for i in range(7):
    print(ip.read_buffer_address(i))
# Out:
# 0
# 313344
# 104448
# 110592
# 208896
# 307200
# 313344

# %%
def prepare_input_value(value, lshift):
    ret = value * (1 << lshift)
    ret = np.clip(ret, -1 * 2 ** (16 - 1) - 1, 2 ** (16 - 1))
    return np.round(ret.astype(np.float64)).astype(np.int16)

# %%
reference_images = data_npz["reference_image"]
reference_poses = data_npz["reference_pose"]

max_n_measurement_frames = 2
min_depth = 0.25
max_depth = 20.0
inverse_depth_base = 1 / max_depth
inverse_depth_multiplier = 1 / min_depth - 1 / max_depth

test_keyframe_buffer_size = 30
test_keyframe_pose_distance = 0.1
test_optimal_t_measure = 0.15
test_optimal_R_measure = 0.0

calc = lstm_state_calculator(data_npz, prepare_input_value, 14-1)
org_hidden_state = np.zeros((3072), dtype=np.int16)
org_cell_state = np.zeros((3072), dtype=np.int16)

reference_pads = np.zeros([1, 64, 96, 5], dtype=np.int16)

# %%
half_K = data_npz["half_K"][0]
inv_half_K = np.linalg.inv(half_K)

def get_warp_grid_for_cost_volume_calculation(width, height):
    x = np.linspace(0, width - 1, num=int(width))
    y = np.linspace(0, height - 1, num=int(height))
    ones = np.ones(shape=(height, width))
    x_grid, y_grid = np.meshgrid(x, y)
    warp_grid = np.stack((x_grid, y_grid, ones), axis=-1)
    warp_grid = warp_grid.astype(np.float32).reshape(-1, 3).T
    return warp_grid
warp_grid = get_warp_grid_for_cost_volume_calculation(int(96 / 2), int(64 / 2))

def round_and_clip(input):
    info = np.iinfo(np.int16)
    return np.clip(np.round(input).astype(np.int64), info.min, info.max).astype(np.int16)

# %%
# opcode -> (func, input.addr, input.aligned_shape, output.addr, output.aligned_shape)
externs = {0x79: (None, 0, (1, 32, 48, 32), 175680960, (1, 32, 48, 64)),
           0x102: (None, 307200, (1, 32, 48, 512), hidden_state_offset, (1, 32, 48, 512)),
           0x104: (ln(12), 176912832, (1, 2, 3, 512), 176931264, (1, 2, 3, 512)),
           0x105: (ln(12), 176937408, (1, 2, 3, 512), cell_state_offset, (1, 2, 3, 512)),
           0x107: (interpolate(4, 6, 0, 'bilinear'), 104448, (1, 2, 3, 512), 176949696, (1, 4, 6, 512)),
           0x113: (interpolate(8, 12, 0, 'bilinear'), 177035712, (1, 4, 6, 256), 177048000, (1, 8, 12, 256)),
           0x115: (interpolate(8, 12, 0, 'bilinear'), 177097152, (1, 4, 6, 8), 177097536, (1, 8, 12, 8)),
           0x120: (interpolate(16, 24, 0, 'bilinear'), 177200448, (1, 8, 12, 128), 177225024, (1, 16, 24, 128)),
           0x122: (interpolate(16, 24, 0, 'bilinear'), 177323328, (1, 8, 12, 8), 177324864, (1, 16, 24, 8)),
           0x127: (interpolate(32, 48, 0, 'bilinear'), 177539904, (1, 16, 24, 64), 177589056, (1, 32, 48, 64)),
           0x129: (interpolate(32, 48, 0, 'bilinear'), 177785664, (1, 16, 24, 8), 177791808, (1, 32, 48, 8)),
           0x134: (interpolate(64, 96, 0, 'bilinear'), 178357056, (1, 32, 48, 8), 178774848, (1, 64, 96, 8)),
           0x135: (interpolate(64, 96, 0, 'bilinear'), 178258752, (1, 32, 48, 32), 178381632, (1, 64, 96, 32))}

# %%
sw = []
hw = []
c2s = {0x79: 801, 0x102:1070, 0x104: 1100, 0x105: 1142, 0x107: 1158, 0x113: 1214, 0x115: 1242, 0x120: 1288, 0x122: 1316, 0x127: 1362, 0x129: 1390, 0x134: 1461, 0x135: 1436}
breaks = [0x102, 0x104, 0x105, 0x107, 0x113, 0x115, 0x120, 0x122, 0x127, 0x129, 0x134, 0x135]
for s in breaks:
    print(s)
    ip.base_ip.write(52, c2s[s])

    def run_extern(code, warped_image2s=None):
        if code == 0x102:
            return None
            
        func, input_addr, input_aligned_shape, output_addr, output_aligned_shape = externs[code]
        input = buf[input_addr:input_addr + shape2size(input_aligned_shape) * (act_bit // 8)].view(np.int16)
        
        start_time = time.time()
        input = input.reshape(input_aligned_shape)
        if input.shape[-1] == 8:
            input = input[:,:,:,:1]
        if warped_image2s is None:
            output = func(input)
        else:
            output = np.array(fusion_quantize_cython(np.array(input), warped_image2s), dtype=np.int16)
        if output.shape != output_aligned_shape:
            output = np.append(output, np.zeros((*output.shape[:-1], 7), dtype=output.dtype), axis=output.ndim-1)
        output = output.astype(np.int16).reshape(-1)
        if code == s:
            sw.append(time.time() - start_time) 
            
        buf[output_addr:output_addr + shape2size(output_aligned_shape) * (act_bit // 8)] = output.view(np.uint8)

        if code == 0x79: return input

    keyframe_buffer = KeyframeBuffer(buffer_size=test_keyframe_buffer_size,
                                    keyframe_pose_distance=test_keyframe_pose_distance,
                                    optimal_t_score=test_optimal_t_measure,
                                    optimal_R_score=test_optimal_R_measure,
                                    store_return_indices=False)
    hidden_state = None
    previous_depth = None
    previous_pose = None

    start_time_total = time.time()

    idx = 0
    depths = []
    for n in range(len(reference_images)):
        start_time = time.time()
        response = keyframe_buffer.try_new_keyframe(reference_poses[n][0])

        print("evaluating %05d.png (response: %d) ..." % (n + 3, response))
        if response == 2 or response == 4 or response == 5:
            continue
        elif response == 3:
            hidden_state = None
            previous_depth = None
            previous_pose = None
            continue

        reference_image_value = prepare_input_value(reference_images[n].transpose(0, 2, 3, 1), 12)
        reference_image_value = np.append(reference_image_value, reference_pads, axis=3).reshape(-1)
        addr = addrs[len(output_files)]
        buf[addr:addr + reference_image_value.size * (act_bit // 8)] = reference_image_value.view(np.uint8)
        
        ip.run()

        if response == 0:
            for i in range(len(externs)):
                code = ip.wait_extern()
                ip.resume_extern()
                if i == 0:
                    _, input_addr, input_aligned_shape, _, _ = externs[code]
                    feature_half_value = buf[input_addr:input_addr + shape2size(input_aligned_shape) * (act_bit // 8)].view(np.int16).reshape(input_aligned_shape)
                    keyframe_buffer.add_new_keyframe(reference_poses[n][0], feature_half_value.copy())
            ip.wait()
            print(time.time() - start_time)
            continue
        
        ### prepare fusion ###
        measurement_poses_value = []
        measurement_features_value = []
        frame_number_value = idx
        measurement_frames = keyframe_buffer.get_best_measurement_frames(reference_poses[n][0], max_n_measurement_frames)
        for measurement_frame in measurement_frames:
            measurement_poses_value.append(measurement_frame[0])
            measurement_features_value.append(measurement_frame[1])

        inv_pose2s = np.linalg.inv(np.array(measurement_poses_value))
        warped_image2s = np.array(prep_cython(len(measurement_frames), np.array(measurement_features_value), half_K, inv_half_K, reference_poses[n][0], inv_pose2s, warp_grid), dtype=np.int16)

        for i in range(len(externs)):
            code = ip.wait_extern()
            if i == 0:
                feature_half_value = run_extern(code, warped_image2s)
                ip.resume_extern()

                ### prepare hidden_state and cell_state ###
                if previous_depth is not None:
                    hidden_state_value = calc(hidden_state, previous_depth, previous_pose, reference_poses[n]).reshape(-1)
                    addr = addrs[hidden_state_idx]
                    buf[addr:addr + hidden_state_value.size * (act_bit // 8)] = hidden_state_value.view(np.uint8)
                else:
                    addr = addrs[hidden_state_idx+1]
                    buf[addr:addr + org_cell_state.size * (act_bit // 8)] = org_cell_state.view(np.uint8)
                    addr = addrs[hidden_state_idx]
                    buf[addr:addr + org_hidden_state.size * (act_bit // 8)] = org_hidden_state.view(np.uint8)
            elif i == 1:
                if code == s:
                    sw.append(0)
                ip.resume_extern()

                keyframe_buffer.add_new_keyframe(reference_poses[n][0], feature_half_value.copy())
            else:
                run_extern(code)
                ip.resume_extern()

        ### prepare hidden_state and cell_state ###
        addr = addrs[2]
        output_aligned_shape = output_aligned_shapes[2]
        hidden_state = buf[addr:addr + shape2size(output_aligned_shape) * (act_bit // 8)].view(np.int16).reshape(output_aligned_shape)

        previous_pose = reference_poses[n]

        ip.wait()

        ### prepare previous_depth and hidden_state ###
        addr = addrs[3]
        output_aligned_shape = output_aligned_shapes[3]
        depth_org = buf[addr:addr + shape2size(output_aligned_shape) * (act_bit // 8)].view(np.int16).reshape(output_aligned_shape)
        depth_org = depth_org[:,:,:,:1]
        depth_org = (depth_org.transpose(0, 3, 1, 2) / (1 << 14)).astype(np.float32)
        inverse_depth_full = inverse_depth_multiplier * depth_org + inverse_depth_base
        previous_depth = 1.0 / inverse_depth_full

        hw.append(ip.base_ip.read(48))
        print(time.time() - start_time)

        depths.append(previous_depth)
        idx += 1
# Out:
# 258
# evaluating 00003.png (response: 0) ...
# 0.23545002937316895
# evaluating 00004.png (response: 1) ...
# 0.6956555843353271
# evaluating 00005.png (response: 1) ...
# 1.5959992408752441
# evaluating 00006.png (response: 1) ...
# 1.323375940322876
# evaluating 00007.png (response: 1) ...
# 1.1967835426330566
# evaluating 00008.png (response: 1) ...
# 0.9146668910980225
# evaluating 00009.png (response: 1) ...
# 0.2724742889404297
# evaluating 00010.png (response: 1) ...
# 0.2720644474029541
# evaluating 00011.png (response: 1) ...
# 0.27106356620788574
# evaluating 00012.png (response: 1) ...
# 0.2716670036315918
# evaluating 00013.png (response: 1) ...
# 0.2717711925506592
# evaluating 00014.png (response: 1) ...
# 0.27188873291015625
# evaluating 00015.png (response: 1) ...
# 0.27355098724365234
# evaluating 00016.png (response: 1) ...
# 0.27149248123168945
# evaluating 00017.png (response: 1) ...
# 0.27232885360717773
# evaluating 00018.png (response: 1) ...
# 0.3186914920806885
# evaluating 00019.png (response: 1) ...
# 0.27200746536254883
# evaluating 00020.png (response: 1) ...
# 0.27037858963012695
# evaluating 00021.png (response: 1) ...
# 0.27205681800842285
# evaluating 00022.png (response: 1) ...
# 0.27190732955932617
# evaluating 00023.png (response: 1) ...
# 0.3144094944000244
# evaluating 00024.png (response: 1) ...
# 0.27445030212402344
# evaluating 00025.png (response: 1) ...
# 0.27225828170776367
# evaluating 00026.png (response: 1) ...
# 0.27096080780029297
# evaluating 00027.png (response: 1) ...
# 0.2787163257598877
# evaluating 00028.png (response: 1) ...
# 0.2720170021057129
# evaluating 00029.png (response: 1) ...
# 0.2709016799926758
# evaluating 00030.png (response: 1) ...
# 0.27304649353027344
# evaluating 00031.png (response: 1) ...
# 0.27068257331848145
# evaluating 00032.png (response: 1) ...
# 0.28938937187194824
# evaluating 00025.png (response: 1) ...
# 0.27135729789733887
# evaluating 00026.png (response: 1) ...
# 0.2727818489074707
# evaluating 00027.png (response: 1) ...
# 0.27181220054626465
# evaluating 00028.png (response: 1) ...
# 0.2709338665008545
# evaluating 00029.png (response: 1) ...
# 0.2712738513946533
# evaluating 00030.png (response: 1) ...
# 0.2720019817352295
# evaluating 00031.png (response: 1) ...
# 0.27185654640197754
# evaluating 00032.png (response: 1) ...
# 0.30207204818725586
# evaluating 00033.png (response: 1) ...
# 0.27152466773986816
# evaluating 00034.png (response: 1) ...
# 0.27124786376953125
# evaluating 00035.png (response: 1) ...
# 0.2776145935058594
# evaluating 00036.png (response: 1) ...
# 0.27143287658691406
# evaluating 00037.png (response: 1) ...
# 0.27359676361083984
# evaluating 00038.png (response: 1) ...
# 0.2754690647125244
# evaluating 00039.png (response: 1) ...
# 0.27709007263183594
# evaluating 00040.png (response: 1) ...
# 0.27355408668518066
# evaluating 00041.png (response: 1) ...
# 0.27649855613708496
# evaluating 00042.png (response: 1) ...
# 0.27789974212646484
# evaluating 00043.png (response: 1) ...
# 0.2742908000946045
# evaluating 00044.png (response: 1) ...
# 0.27088093757629395
# evaluating 00045.png (response: 1) ...
# 0.2711355686187744
# evaluating 00046.png (response: 1) ...
# 0.2761869430541992
# evaluating 00047.png (response: 1) ...
# 0.2763693332672119
# evaluating 00048.png (response: 1) ...
# 0.2761213779449463
# evaluating 00049.png (response: 1) ...
# 0.27348875999450684
# evaluating 00050.png (response: 1) ...
# 0.27536582946777344
# evaluating 00051.png (response: 1) ...
# 0.2764012813568115
# evaluating 00052.png (response: 1) ...
# 0.274125337600708
# evaluating 00053.png (response: 1) ...
# 0.27117156982421875
# evaluating 00054.png (response: 1) ...
# 0.2716391086578369
# evaluating 00055.png (response: 1) ...
# 0.27219343185424805
# evaluating 00056.png (response: 1) ...
# 0.33016037940979004
# evaluating 00057.png (response: 1) ...
# 0.27068638801574707
# evaluating 00058.png (response: 1) ...
# 0.2722318172454834
# evaluating 00059.png (response: 1) ...
# 0.332383394241333
# evaluating 00060.png (response: 1) ...
# 0.2710306644439697
# evaluating 00061.png (response: 1) ...
# 0.2716834545135498
# evaluating 00062.png (response: 1) ...
# 0.2738666534423828
# evaluating 00063.png (response: 1) ...
# 0.2728917598724365
# evaluating 00064.png (response: 1) ...
# 0.2727625370025635
# evaluating 00065.png (response: 1) ...
# 0.317457914352417
# evaluating 00066.png (response: 1) ...
# 0.27123451232910156
# evaluating 00067.png (response: 1) ...
# 0.2734830379486084
# evaluating 00068.png (response: 1) ...
# 0.32614731788635254
# evaluating 00069.png (response: 1) ...
# 0.2712850570678711
# evaluating 00070.png (response: 1) ...
# 0.2713487148284912
# evaluating 00071.png (response: 1) ...
# 0.2715611457824707
# evaluating 00072.png (response: 1) ...
# 0.2714579105377197
# evaluating 00073.png (response: 1) ...
# 0.2716844081878662
# evaluating 00074.png (response: 1) ...
# 0.27156805992126465
# evaluating 00075.png (response: 1) ...
# 0.27112364768981934
# evaluating 00068.png (response: 1) ...
# 0.2712242603302002
# evaluating 00069.png (response: 1) ...
# 0.2720193862915039
# evaluating 00070.png (response: 1) ...
# 0.3268547058105469
# evaluating 00071.png (response: 1) ...
# 0.32525157928466797
# evaluating 00072.png (response: 1) ...
# 0.2711367607116699
# evaluating 00073.png (response: 1) ...
# 0.2710287570953369
# evaluating 00074.png (response: 1) ...
# 0.2718024253845215
# evaluating 00075.png (response: 1) ...
# 0.271373987197876
# evaluating 00076.png (response: 1) ...
# 0.2714579105377197
# evaluating 00077.png (response: 1) ...
# 0.2718384265899658
# evaluating 00078.png (response: 1) ...
# 0.2719993591308594
# evaluating 00079.png (response: 1) ...
# 0.2790243625640869
# evaluating 00080.png (response: 1) ...
# 0.2822399139404297
# evaluating 00081.png (response: 1) ...
# 0.275054931640625
# evaluating 00082.png (response: 1) ...
# 0.3105318546295166
# evaluating 00083.png (response: 1) ...
# 0.27155375480651855
# evaluating 00084.png (response: 1) ...
# 0.2715299129486084
# evaluating 00085.png (response: 1) ...
# 0.27206993103027344
# evaluating 00086.png (response: 1) ...
# 0.27161097526550293
# evaluating 00087.png (response: 1) ...
# 0.2716348171234131
# evaluating 00088.png (response: 1) ...
# 0.2719855308532715
# evaluating 00089.png (response: 1) ...
# 0.27156782150268555
# evaluating 00090.png (response: 1) ...
# 0.2714550495147705
# evaluating 00091.png (response: 1) ...
# 0.2716968059539795
# evaluating 00092.png (response: 1) ...
# 0.27144312858581543
# evaluating 00093.png (response: 1) ...
# 0.27147841453552246
# evaluating 00094.png (response: 1) ...
# 0.2725338935852051
# evaluating 00095.png (response: 1) ...
# 0.348203182220459
# evaluating 00096.png (response: 1) ...
# 0.43256425857543945
# evaluating 00097.png (response: 1) ...
# 0.2722046375274658
# evaluating 00098.png (response: 1) ...
# 0.2742800712585449
# evaluating 00099.png (response: 1) ...
# 0.2711656093597412
# evaluating 00100.png (response: 1) ...
# 0.2731969356536865
# evaluating 00101.png (response: 1) ...
# 0.2713282108306885
# evaluating 00102.png (response: 1) ...
# 0.2719132900238037
# evaluating 00103.png (response: 1) ...
# 0.2715315818786621
# evaluating 00104.png (response: 1) ...
# 0.27265024185180664
# evaluating 00105.png (response: 1) ...
# 0.3124074935913086
# evaluating 00106.png (response: 1) ...
# 0.2710385322570801
# evaluating 00107.png (response: 1) ...
# 0.27460646629333496
# evaluating 00108.png (response: 1) ...
# 0.272388219833374
# evaluating 00109.png (response: 1) ...
# 0.2720930576324463
# evaluating 00110.png (response: 1) ...
# 0.27513813972473145
# evaluating 00111.png (response: 1) ...
# 0.2712440490722656
# evaluating 00112.png (response: 1) ...
# 0.2723863124847412
# 263
# evaluating 00003.png (response: 0) ...
# 0.22958660125732422
# evaluating 00004.png (response: 1) ...
# 0.2737390995025635
# evaluating 00005.png (response: 1) ...
# 0.2727394104003906
# evaluating 00006.png (response: 1) ...
# 0.32419538497924805
# evaluating 00007.png (response: 1) ...
# 0.27222728729248047
# evaluating 00008.png (response: 1) ...
# 0.27168941497802734
# evaluating 00009.png (response: 1) ...
# 0.272540807723999
# evaluating 00010.png (response: 1) ...
# 0.3172948360443115
# evaluating 00011.png (response: 1) ...
# 0.2712383270263672
# evaluating 00012.png (response: 1) ...
# 0.27252697944641113
# evaluating 00013.png (response: 1) ...
# 0.2715277671813965
# evaluating 00014.png (response: 1) ...
# 0.2775700092315674
# evaluating 00015.png (response: 1) ...
# 0.27115702629089355
# evaluating 00016.png (response: 1) ...
# 0.2734224796295166
# evaluating 00017.png (response: 1) ...
# 0.27147388458251953
# evaluating 00018.png (response: 1) ...
# 0.2722296714782715
# evaluating 00019.png (response: 1) ...
# 0.4617903232574463
# evaluating 00020.png (response: 1) ...
# 0.2712888717651367
# evaluating 00021.png (response: 1) ...
# 0.2714345455169678
# evaluating 00022.png (response: 1) ...
# 0.27199387550354004
# evaluating 00023.png (response: 1) ...
# 0.2715613842010498
# evaluating 00024.png (response: 1) ...
# 0.2713630199432373
# evaluating 00025.png (response: 1) ...
# 0.27118706703186035
# evaluating 00026.png (response: 1) ...
# 0.27109766006469727
# evaluating 00027.png (response: 1) ...
# 0.2699854373931885
# evaluating 00028.png (response: 1) ...
# 0.30747318267822266
# evaluating 00029.png (response: 1) ...
# 0.27147674560546875
# evaluating 00030.png (response: 1) ...
# 0.2715282440185547
# evaluating 00031.png (response: 1) ...
# 0.3203432559967041
# evaluating 00032.png (response: 1) ...
# 0.279526948928833
# evaluating 00033.png (response: 1) ...
# 0.27095460891723633
# evaluating 00034.png (response: 1) ...
# 0.2725207805633545
# evaluating 00035.png (response: 1) ...
# 0.3055689334869385
# evaluating 00036.png (response: 1) ...
# 0.27057743072509766
# evaluating 00037.png (response: 1) ...
# 0.27265453338623047
# evaluating 00038.png (response: 1) ...
# 0.30767107009887695
# evaluating 00039.png (response: 1) ...
# 0.2712435722351074
# evaluating 00040.png (response: 1) ...
# 0.2748739719390869
# evaluating 00041.png (response: 1) ...
# 0.28182125091552734
# evaluating 00042.png (response: 1) ...
# 0.27126312255859375
# evaluating 00043.png (response: 1) ...
# 0.2710847854614258
# evaluating 00044.png (response: 1) ...
# 0.27129411697387695
# evaluating 00045.png (response: 1) ...
# 0.2704775333404541
# evaluating 00046.png (response: 1) ...
# 0.27132558822631836
# evaluating 00047.png (response: 1) ...
# 0.2715458869934082
# evaluating 00048.png (response: 1) ...
# 0.2711338996887207
# evaluating 00049.png (response: 1) ...
# 0.27582502365112305
# evaluating 00050.png (response: 1) ...
# 0.27292442321777344
# evaluating 00051.png (response: 1) ...
# 0.2710692882537842
# evaluating 00052.png (response: 1) ...
# 0.2714502811431885
# evaluating 00053.png (response: 1) ...
# 0.27121663093566895
# evaluating 00054.png (response: 1) ...
# 0.2711608409881592
# evaluating 00055.png (response: 1) ...
# 0.27137112617492676
# evaluating 00056.png (response: 1) ...
# 0.2710881233215332
# evaluating 00057.png (response: 1) ...
# 0.27821826934814453
# evaluating 00058.png (response: 1) ...
# 0.2925229072570801
# evaluating 00059.png (response: 1) ...
# 0.27144551277160645
# evaluating 00060.png (response: 1) ...
# 0.2713899612426758
# evaluating 00061.png (response: 1) ...
# 0.27126574516296387
# evaluating 00062.png (response: 1) ...
# 0.27111315727233887
# evaluating 00063.png (response: 1) ...
# 0.27151036262512207
# evaluating 00064.png (response: 1) ...
# 0.2831878662109375
# evaluating 00065.png (response: 1) ...
# 0.27233386039733887
# evaluating 00066.png (response: 1) ...
# 0.33486437797546387
# evaluating 00067.png (response: 1) ...
# 0.27033305168151855
# evaluating 00068.png (response: 1) ...
# 0.273956298828125
# evaluating 00069.png (response: 1) ...
# 0.3321113586425781
# evaluating 00070.png (response: 1) ...
# 0.4255690574645996
# evaluating 00071.png (response: 1) ...
# 0.27726078033447266
# evaluating 00072.png (response: 1) ...
# 0.3256559371948242
# evaluating 00073.png (response: 1) ...
# 0.27098965644836426
# evaluating 00074.png (response: 1) ...
# 0.2714526653289795
# evaluating 00075.png (response: 1) ...
# 0.27147507667541504
# evaluating 00076.png (response: 1) ...
# 0.2709946632385254
# evaluating 00077.png (response: 1) ...
# 0.2724776268005371
# evaluating 00078.png (response: 1) ...
# 0.32404589653015137
# evaluating 00079.png (response: 1) ...
# 0.27135777473449707
# evaluating 00080.png (response: 1) ...
# 0.27145910263061523
# evaluating 00081.png (response: 1) ...
# 0.2715721130371094
# evaluating 00082.png (response: 1) ...
# 0.2713189125061035
# evaluating 00083.png (response: 1) ...
# 0.27134132385253906
# evaluating 00084.png (response: 1) ...
# 0.2711918354034424
# evaluating 00085.png (response: 1) ...
# 0.2710390090942383
# evaluating 00086.png (response: 1) ...
# 0.27091264724731445
# evaluating 00087.png (response: 1) ...
# 0.2719130516052246
# evaluating 00088.png (response: 1) ...
# 0.32677507400512695
# evaluating 00089.png (response: 1) ...
# 0.27039337158203125
# evaluating 00090.png (response: 1) ...
# 0.28136181831359863
# evaluating 00091.png (response: 1) ...
# 0.27231383323669434
# evaluating 00092.png (response: 1) ...
# 0.32239556312561035
# evaluating 00093.png (response: 1) ...
# 0.2712082862854004
# evaluating 00094.png (response: 1) ...
# 0.27333498001098633
# evaluating 00095.png (response: 1) ...
# 0.3070042133331299
# evaluating 00096.png (response: 1) ...
# 0.27834534645080566
# evaluating 00097.png (response: 1) ...
# 0.27469468116760254
# evaluating 00098.png (response: 1) ...
# 0.32401180267333984
# evaluating 00099.png (response: 1) ...
# 0.27114152908325195
# evaluating 00100.png (response: 1) ...
# 0.2712984085083008
# evaluating 00101.png (response: 1) ...
# 0.2711501121520996
# evaluating 00102.png (response: 1) ...
# 0.2710249423980713
# evaluating 00103.png (response: 1) ...
# 0.27083539962768555
# evaluating 00104.png (response: 1) ...
# 0.2714226245880127
# evaluating 00105.png (response: 1) ...
# 0.2718644142150879
# evaluating 00106.png (response: 1) ...
# 0.27130556106567383
# evaluating 00107.png (response: 1) ...
# 0.2714221477508545
# evaluating 00108.png (response: 1) ...
# 0.27135252952575684
# evaluating 00109.png (response: 1) ...
# 0.27114105224609375
# evaluating 00110.png (response: 1) ...
# 0.2725367546081543
# evaluating 00052.png (response: 1) ...
# 0.32772231101989746
# evaluating 00053.png (response: 1) ...
# 0.3168652057647705
# evaluating 00054.png (response: 1) ...
# 0.27132415771484375
# evaluating 00055.png (response: 1) ...
# 0.2711949348449707
# evaluating 00056.png (response: 1) ...
# 0.27166318893432617
# evaluating 00057.png (response: 1) ...
# 0.27149224281311035
# evaluating 00058.png (response: 1) ...
# 0.2714650630950928
# evaluating 00059.png (response: 1) ...
# 0.2732982635498047
# evaluating 00060.png (response: 1) ...
# 0.32185959815979004
# evaluating 00061.png (response: 1) ...
# 0.27089738845825195
# evaluating 00062.png (response: 1) ...
# 0.27172017097473145
# evaluating 00063.png (response: 1) ...
# 0.27135515213012695
# evaluating 00064.png (response: 1) ...
# 0.2716202735900879
# evaluating 00065.png (response: 1) ...
# 0.2715728282928467
# evaluating 00066.png (response: 1) ...
# 0.27169036865234375
# evaluating 00067.png (response: 1) ...
# 0.2714078426361084
# evaluating 00068.png (response: 1) ...
# 0.2713899612426758
# evaluating 00069.png (response: 1) ...
# 0.2712435722351074
# evaluating 00070.png (response: 1) ...
# 0.27050256729125977
# evaluating 00071.png (response: 1) ...
# 0.2795076370239258
# evaluating 00072.png (response: 1) ...
# 0.2715489864349365
# evaluating 00073.png (response: 1) ...
# 0.2712862491607666
# evaluating 00074.png (response: 1) ...
# 0.2716078758239746
# evaluating 00075.png (response: 1) ...
# 0.2716655731201172
# evaluating 00076.png (response: 1) ...
# 0.2713744640350342
# evaluating 00077.png (response: 1) ...
# 0.2715442180633545
# evaluating 00078.png (response: 1) ...
# 0.27144956588745117
# evaluating 00079.png (response: 1) ...
# 0.2716045379638672
# evaluating 00080.png (response: 1) ...
# 0.2716362476348877
# evaluating 00081.png (response: 1) ...
# 0.27251482009887695
# evaluating 00082.png (response: 1) ...
# 0.27158141136169434
# evaluating 00083.png (response: 1) ...
# 0.27173686027526855
# evaluating 00084.png (response: 1) ...
# 0.27144742012023926
# evaluating 00085.png (response: 1) ...
# 0.2737588882446289
# evaluating 00086.png (response: 1) ...
# 0.3144266605377197
# evaluating 00087.png (response: 1) ...
# 0.271026611328125
# evaluating 00088.png (response: 1) ...
# 0.27166295051574707
# evaluating 00089.png (response: 1) ...
# 0.4470193386077881
# evaluating 00090.png (response: 1) ...
# 0.2712209224700928
# evaluating 00091.png (response: 1) ...
# 0.271242618560791
# evaluating 00092.png (response: 1) ...
# 0.27120018005371094
# evaluating 00093.png (response: 1) ...
# 0.27140021324157715
# evaluating 00094.png (response: 1) ...
# 0.27165937423706055
# evaluating 00095.png (response: 1) ...
# 0.2711827754974365
# evaluating 00096.png (response: 1) ...
# 0.36537647247314453
# evaluating 00097.png (response: 1) ...
# 0.321688175201416
# evaluating 00098.png (response: 1) ...
# 0.27131009101867676
# evaluating 00099.png (response: 1) ...
# 0.27367472648620605
# evaluating 00100.png (response: 1) ...
# 0.27373528480529785
# evaluating 00101.png (response: 1) ...
# 0.2767620086669922
# evaluating 00102.png (response: 1) ...
# 0.2758505344390869
# evaluating 00103.png (response: 1) ...
# 0.2714498043060303
# evaluating 00104.png (response: 1) ...
# 0.2716033458709717
# evaluating 00105.png (response: 1) ...
# 0.2800116539001465
# evaluating 00106.png (response: 1) ...
# 0.30350160598754883
# evaluating 00107.png (response: 1) ...
# 0.2729771137237549
# evaluating 00108.png (response: 1) ...
# 0.27617931365966797
# evaluating 00109.png (response: 1) ...
# 0.2714817523956299
# evaluating 00110.png (response: 1) ...
# 0.27155518531799316
# evaluating 00111.png (response: 1) ...
# 0.27143025398254395
# evaluating 00112.png (response: 1) ...
# 0.27561497688293457
# 277
# evaluating 00003.png (response: 0) ...
# 0.2299048900604248
# evaluating 00004.png (response: 1) ...
# 0.27204298973083496
# evaluating 00005.png (response: 1) ...
# 0.2718806266784668
# evaluating 00006.png (response: 1) ...
# 0.2718837261199951
# evaluating 00007.png (response: 1) ...
# 0.27141594886779785
# evaluating 00008.png (response: 1) ...
# 0.2714390754699707
# evaluating 00009.png (response: 1) ...
# 0.2717010974884033
# evaluating 00010.png (response: 1) ...
# 0.2716069221496582
# evaluating 00011.png (response: 1) ...
# 0.27129292488098145
# evaluating 00012.png (response: 1) ...
# 0.2715795040130615
# evaluating 00013.png (response: 1) ...
# 0.2712998390197754
# evaluating 00014.png (response: 1) ...
# 0.2714869976043701
# evaluating 00015.png (response: 1) ...
# 0.2712681293487549
# evaluating 00016.png (response: 1) ...
# 0.2723534107208252
# evaluating 00017.png (response: 1) ...
# 0.2713594436645508
# evaluating 00018.png (response: 1) ...
# 0.2713587284088135
# evaluating 00019.png (response: 1) ...
# 0.2710397243499756
# evaluating 00020.png (response: 1) ...
# 0.2710897922515869
# evaluating 00021.png (response: 1) ...
# 0.27142810821533203
# evaluating 00022.png (response: 1) ...
# 0.2714414596557617
# evaluating 00023.png (response: 1) ...
# 0.27158045768737793
# evaluating 00024.png (response: 1) ...
# 0.27147626876831055
# evaluating 00025.png (response: 1) ...
# 0.2822873592376709
# evaluating 00026.png (response: 1) ...
# 0.4859333038330078
# evaluating 00027.png (response: 1) ...
# 0.27111029624938965
# evaluating 00028.png (response: 1) ...
# 0.2705378532409668
# evaluating 00029.png (response: 1) ...
# 0.2743825912475586
# evaluating 00030.png (response: 1) ...
# 0.2711830139160156
# evaluating 00031.png (response: 1) ...
# 0.271500825881958
# evaluating 00032.png (response: 1) ...
# 0.2711946964263916
# evaluating 00033.png (response: 1) ...
# 0.27188992500305176
# evaluating 00034.png (response: 1) ...
# 0.27148866653442383
# evaluating 00035.png (response: 1) ...
# 0.271526575088501
# evaluating 00036.png (response: 1) ...
# 0.27185702323913574
# evaluating 00037.png (response: 1) ...
# 0.2716813087463379
# evaluating 00038.png (response: 1) ...
# 0.27109575271606445
# evaluating 00039.png (response: 1) ...
# 0.2710092067718506
# evaluating 00040.png (response: 1) ...
# 0.2713291645050049
# evaluating 00041.png (response: 1) ...
# 0.27218079566955566
# evaluating 00042.png (response: 1) ...
# 0.27120423316955566
# evaluating 00043.png (response: 1) ...
# 0.27116942405700684
# evaluating 00044.png (response: 1) ...
# 0.2711343765258789
# evaluating 00045.png (response: 1) ...
# 0.27151012420654297
# evaluating 00046.png (response: 1) ...
# 0.2713510990142822
# evaluating 00047.png (response: 1) ...
# 0.2715466022491455
# evaluating 00048.png (response: 1) ...
# 0.2716948986053467
# evaluating 00049.png (response: 1) ...
# 0.2713196277618408
# evaluating 00050.png (response: 1) ...
# 0.2714347839355469
# evaluating 00051.png (response: 1) ...
# 0.27182579040527344
# evaluating 00052.png (response: 1) ...
# 0.27143073081970215
# evaluating 00053.png (response: 1) ...
# 0.27146434783935547
# evaluating 00054.png (response: 1) ...
# 0.2714838981628418
# evaluating 00055.png (response: 1) ...
# 0.27381134033203125
# evaluating 00056.png (response: 1) ...
# 0.2712733745574951
# evaluating 00057.png (response: 1) ...
# 0.2710843086242676
# evaluating 00058.png (response: 1) ...
# 0.27097582817077637
# evaluating 00059.png (response: 1) ...
# 0.27126121520996094
# evaluating 00060.png (response: 1) ...
# 0.27135229110717773
# evaluating 00061.png (response: 1) ...
# 0.27104806900024414
# evaluating 00062.png (response: 1) ...
# 0.2716214656829834
# evaluating 00063.png (response: 1) ...
# 0.2714555263519287
# evaluating 00064.png (response: 1) ...
# 0.271406888961792
# evaluating 00065.png (response: 1) ...
# 0.27126407623291016
# evaluating 00066.png (response: 1) ...
# 0.27083301544189453
# evaluating 00067.png (response: 1) ...
# 0.27145862579345703
# evaluating 00068.png (response: 1) ...
# 0.2710554599761963
# evaluating 00069.png (response: 1) ...
# 0.2716691493988037
# evaluating 00070.png (response: 1) ...
# 0.27246737480163574
# evaluating 00071.png (response: 1) ...
# 0.46768760681152344
# evaluating 00072.png (response: 1) ...
# 0.2715280055999756
# evaluating 00073.png (response: 1) ...
# 0.2714195251464844
# evaluating 00074.png (response: 1) ...
# 0.271437406539917
# evaluating 00075.png (response: 1) ...
# 0.2712833881378174
# evaluating 00076.png (response: 1) ...
# 0.27154016494750977
# evaluating 00077.png (response: 1) ...
# 0.2758927345275879
# evaluating 00078.png (response: 1) ...
# 0.27155613899230957
# evaluating 00079.png (response: 1) ...
# 0.2711219787597656
# evaluating 00080.png (response: 1) ...
# 0.2713003158569336
# evaluating 00081.png (response: 1) ...
# 0.270740270614624
# evaluating 00082.png (response: 1) ...
# 0.2709932327270508
# evaluating 00083.png (response: 1) ...
# 0.2712714672088623
# evaluating 00084.png (response: 1) ...
# 0.2717256546020508
# evaluating 00085.png (response: 1) ...
# 0.2701609134674072
# evaluating 00086.png (response: 1) ...
# 0.30369114875793457
# evaluating 00087.png (response: 1) ...
# 0.2716062068939209
# evaluating 00088.png (response: 1) ...
# 0.27138638496398926
# evaluating 00089.png (response: 1) ...
# 0.2713894844055176
# evaluating 00090.png (response: 1) ...
# 0.2713358402252197
# evaluating 00091.png (response: 1) ...
# 0.27165794372558594
# evaluating 00092.png (response: 1) ...
# 0.2713193893432617
# evaluating 00093.png (response: 1) ...
# 0.2713923454284668
# evaluating 00094.png (response: 1) ...
# 0.2713313102722168
# evaluating 00095.png (response: 1) ...
# 0.2715122699737549
# evaluating 00096.png (response: 1) ...
# 0.2717604637145996
# evaluating 00097.png (response: 1) ...
# 0.27130937576293945
# evaluating 00098.png (response: 1) ...
# 0.27270007133483887
# evaluating 00099.png (response: 1) ...
# 0.2722952365875244
# evaluating 00100.png (response: 1) ...
# 0.27132678031921387
# evaluating 00101.png (response: 1) ...
# 0.2714226245880127
# evaluating 00102.png (response: 1) ...
# 0.2718644142150879
# evaluating 00103.png (response: 1) ...
# 0.2711069583892822
# evaluating 00104.png (response: 1) ...
# 0.27138829231262207
# evaluating 00105.png (response: 1) ...
# 0.2713618278503418
# evaluating 00106.png (response: 1) ...
# 0.27167272567749023
# evaluating 00107.png (response: 1) ...
# 0.2712061405181885
# evaluating 00108.png (response: 1) ...
# 0.27107810974121094
# evaluating 00109.png (response: 1) ...
# 0.27187442779541016
# evaluating 00110.png (response: 1) ...
# 0.27134203910827637
# evaluating 00111.png (response: 1) ...
# 0.27184200286865234
# evaluating 00112.png (response: 1) ...
# 0.5320816040039062
# 288
# evaluating 00003.png (response: 0) ...
# 0.2295682430267334
# evaluating 00004.png (response: 1) ...
# 0.27204442024230957
# evaluating 00005.png (response: 1) ...
# 0.27153992652893066
# evaluating 00006.png (response: 1) ...
# 0.2717888355255127
# evaluating 00007.png (response: 1) ...
# 0.27130126953125
# evaluating 00008.png (response: 1) ...
# 0.271864652633667
# evaluating 00009.png (response: 1) ...
# 0.27164793014526367
# evaluating 00010.png (response: 1) ...
# 0.27161526679992676
# evaluating 00011.png (response: 1) ...
# 0.27143311500549316
# evaluating 00012.png (response: 1) ...
# 0.27159690856933594
# evaluating 00013.png (response: 1) ...
# 0.27689194679260254
# evaluating 00014.png (response: 1) ...
# 0.27191948890686035
# evaluating 00015.png (response: 1) ...
# 0.2721536159515381
# evaluating 00016.png (response: 1) ...
# 0.2714369297027588
# evaluating 00017.png (response: 1) ...
# 0.3054349422454834
# evaluating 00018.png (response: 1) ...
# 0.2714505195617676
# evaluating 00019.png (response: 1) ...
# 0.2711305618286133
# evaluating 00020.png (response: 1) ...
# 0.27161717414855957
# evaluating 00021.png (response: 1) ...
# 0.2712581157684326
# evaluating 00022.png (response: 1) ...
# 0.2720179557800293
# evaluating 00023.png (response: 1) ...
# 0.2715315818786621
# evaluating 00024.png (response: 1) ...
# 0.271956205368042
# evaluating 00025.png (response: 1) ...
# 0.27159571647644043
# evaluating 00026.png (response: 1) ...
# 0.27123260498046875
# evaluating 00027.png (response: 1) ...
# 0.2709922790527344
# evaluating 00028.png (response: 1) ...
# 0.2714400291442871
# evaluating 00029.png (response: 1) ...
# 0.2714047431945801
# evaluating 00030.png (response: 1) ...
# 0.2714521884918213
# evaluating 00031.png (response: 1) ...
# 0.27118635177612305
# evaluating 00032.png (response: 1) ...
# 0.2716796398162842
# evaluating 00033.png (response: 1) ...
# 0.27072930335998535
# evaluating 00034.png (response: 1) ...
# 0.2844853401184082
# evaluating 00035.png (response: 1) ...
# 0.27191996574401855
# evaluating 00036.png (response: 1) ...
# 0.271390438079834
# evaluating 00037.png (response: 1) ...
# 0.27175259590148926
# evaluating 00038.png (response: 1) ...
# 0.2719688415527344
# evaluating 00039.png (response: 1) ...
# 0.272233247756958
# evaluating 00040.png (response: 1) ...
# 0.27120137214660645
# evaluating 00041.png (response: 1) ...
# 0.2714395523071289
# evaluating 00042.png (response: 1) ...
# 0.2716090679168701
# evaluating 00043.png (response: 1) ...
# 0.2719991207122803
# evaluating 00044.png (response: 1) ...
# 0.27130651473999023
# evaluating 00045.png (response: 1) ...
# 0.4793856143951416
# evaluating 00046.png (response: 1) ...
# 0.27182960510253906
# evaluating 00047.png (response: 1) ...
# 0.27146148681640625
# evaluating 00048.png (response: 1) ...
# 0.2714231014251709
# evaluating 00049.png (response: 1) ...
# 0.2722756862640381
# evaluating 00050.png (response: 1) ...
# 0.2715733051300049
# evaluating 00051.png (response: 1) ...
# 0.27237606048583984
# evaluating 00052.png (response: 1) ...
# 0.27168893814086914
# evaluating 00053.png (response: 1) ...
# 0.2707252502441406
# evaluating 00054.png (response: 1) ...
# 0.27133655548095703
# evaluating 00055.png (response: 1) ...
# 0.27169084548950195
# evaluating 00056.png (response: 1) ...
# 0.2712514400482178
# evaluating 00057.png (response: 1) ...
# 0.27145934104919434
# evaluating 00058.png (response: 1) ...
# 0.2716715335845947
# evaluating 00059.png (response: 1) ...
# 0.27149438858032227
# evaluating 00060.png (response: 1) ...
# 0.27196431159973145
# evaluating 00061.png (response: 1) ...
# 0.27169132232666016
# evaluating 00062.png (response: 1) ...
# 0.2711951732635498
# evaluating 00063.png (response: 1) ...
# 0.27120113372802734
# evaluating 00064.png (response: 1) ...
# 0.2714073657989502
# evaluating 00065.png (response: 1) ...
# 0.27163171768188477
# evaluating 00066.png (response: 1) ...
# 0.271608829498291
# evaluating 00067.png (response: 1) ...
# 0.27200961112976074
# evaluating 00068.png (response: 1) ...
# 0.27225661277770996
# evaluating 00069.png (response: 1) ...
# 0.27266502380371094
# evaluating 00070.png (response: 1) ...
# 0.2709622383117676
# evaluating 00071.png (response: 1) ...
# 0.27132630348205566
# evaluating 00072.png (response: 1) ...
# 0.27136707305908203
# evaluating 00073.png (response: 1) ...
# 0.272214412689209
# evaluating 00074.png (response: 1) ...
# 0.2710449695587158
# evaluating 00075.png (response: 1) ...
# 0.2713956832885742
# evaluating 00076.png (response: 1) ...
# 0.27132081985473633
# evaluating 00077.png (response: 1) ...
# 0.27175450325012207
# evaluating 00078.png (response: 1) ...
# 0.2718219757080078
# evaluating 00079.png (response: 1) ...
# 0.27162671089172363
# evaluating 00080.png (response: 1) ...
# 0.2714083194732666
# evaluating 00081.png (response: 1) ...
# 0.2716095447540283
# evaluating 00082.png (response: 1) ...
# 0.27136945724487305
# evaluating 00083.png (response: 1) ...
# 0.27147698402404785
# evaluating 00084.png (response: 1) ...
# 0.2713596820831299
# evaluating 00085.png (response: 1) ...
# 0.2708261013031006
# evaluating 00086.png (response: 1) ...
# 0.27338743209838867
# evaluating 00087.png (response: 1) ...
# 0.2713043689727783
# evaluating 00088.png (response: 1) ...
# 0.513253927230835
# evaluating 00089.png (response: 1) ...
# 0.27130889892578125
# evaluating 00090.png (response: 1) ...
# 0.2710585594177246
# evaluating 00091.png (response: 1) ...
# 0.27115321159362793
# evaluating 00092.png (response: 1) ...
# 0.28369712829589844
# evaluating 00093.png (response: 1) ...
# 0.42650485038757324
# evaluating 00094.png (response: 1) ...
# 0.2712554931640625
# evaluating 00095.png (response: 1) ...
# 0.27183079719543457
# evaluating 00096.png (response: 1) ...
# 0.2713325023651123
# evaluating 00097.png (response: 1) ...
# 0.27151012420654297
# evaluating 00098.png (response: 1) ...
# 0.27124452590942383
# evaluating 00099.png (response: 1) ...
# 0.2717568874359131
# evaluating 00100.png (response: 1) ...
# 0.2712674140930176
# evaluating 00101.png (response: 1) ...
# 0.27140069007873535
# evaluating 00102.png (response: 1) ...
# 0.2712442874908447
# evaluating 00103.png (response: 1) ...
# 0.27198338508605957
# evaluating 00104.png (response: 1) ...
# 0.2723076343536377
# evaluating 00105.png (response: 1) ...
# 0.2947812080383301
# evaluating 00106.png (response: 1) ...
# 0.2705564498901367
# evaluating 00107.png (response: 1) ...
# 0.2713437080383301
# evaluating 00108.png (response: 1) ...
# 0.2711958885192871
# evaluating 00109.png (response: 1) ...
# 0.2712690830230713
# evaluating 00110.png (response: 1) ...
# 0.27161121368408203
# evaluating 00111.png (response: 1) ...
# 0.2725188732147217
# evaluating 00112.png (response: 1) ...
# 0.2719388008117676
# 290
# evaluating 00003.png (response: 0) ...
# 0.23010993003845215
# evaluating 00004.png (response: 1) ...
# 0.2728712558746338
# evaluating 00005.png (response: 1) ...
# 0.27195072174072266
# evaluating 00006.png (response: 1) ...
# 0.2724189758300781
# evaluating 00007.png (response: 1) ...
# 0.2717757225036621
# evaluating 00008.png (response: 1) ...
# 0.2718393802642822
# evaluating 00009.png (response: 1) ...
# 0.2716529369354248
# evaluating 00010.png (response: 1) ...
# 0.27184581756591797
# evaluating 00011.png (response: 1) ...
# 0.27257871627807617
# evaluating 00012.png (response: 1) ...
# 0.27239131927490234
# evaluating 00013.png (response: 1) ...
# 0.27176499366760254
# evaluating 00014.png (response: 1) ...
# 0.2722036838531494
# evaluating 00015.png (response: 1) ...
# 0.3193070888519287
# evaluating 00016.png (response: 1) ...
# 0.27150774002075195
# evaluating 00017.png (response: 1) ...
# 0.2720975875854492
# evaluating 00018.png (response: 1) ...
# 0.2716331481933594
# evaluating 00019.png (response: 1) ...
# 0.2719271183013916
# evaluating 00020.png (response: 1) ...
# 0.473160982131958
# evaluating 00021.png (response: 1) ...
# 0.2768712043762207
# evaluating 00022.png (response: 1) ...
# 0.27242040634155273
# evaluating 00023.png (response: 1) ...
# 0.27347350120544434
# evaluating 00024.png (response: 1) ...
# 0.27269506454467773
# evaluating 00025.png (response: 1) ...
# 0.2724173069000244
# evaluating 00026.png (response: 1) ...
# 0.27243828773498535
# evaluating 00027.png (response: 1) ...
# 0.2720973491668701
# evaluating 00028.png (response: 1) ...
# 0.272383451461792
# evaluating 00029.png (response: 1) ...
# 0.2723538875579834
# evaluating 00030.png (response: 1) ...
# 0.2722194194793701
# evaluating 00031.png (response: 1) ...
# 0.2723195552825928
# evaluating 00032.png (response: 1) ...
# 0.27164793014526367
# evaluating 00033.png (response: 1) ...
# 0.2715003490447998
# evaluating 00034.png (response: 1) ...
# 0.27194690704345703
# evaluating 00035.png (response: 1) ...
# 0.27156853675842285
# evaluating 00036.png (response: 1) ...
# 0.27204155921936035
# evaluating 00037.png (response: 1) ...
# 0.27260923385620117
# evaluating 00038.png (response: 1) ...
# 0.2719686031341553
# evaluating 00039.png (response: 1) ...
# 0.2730443477630615
# evaluating 00040.png (response: 1) ...
# 0.27455759048461914
# evaluating 00041.png (response: 1) ...
# 0.27163100242614746
# evaluating 00042.png (response: 1) ...
# 0.29753994941711426
# evaluating 00043.png (response: 1) ...
# 0.27268505096435547
# evaluating 00044.png (response: 1) ...
# 0.2726914882659912
# evaluating 00045.png (response: 1) ...
# 0.271373987197876
# evaluating 00046.png (response: 1) ...
# 0.2721288204193115
# evaluating 00047.png (response: 1) ...
# 0.27418017387390137
# evaluating 00048.png (response: 1) ...
# 0.2710559368133545
# evaluating 00049.png (response: 1) ...
# 0.27651095390319824
# evaluating 00050.png (response: 1) ...
# 0.2724149227142334
# evaluating 00051.png (response: 1) ...
# 0.27129602432250977
# evaluating 00052.png (response: 1) ...
# 0.2714657783508301
# evaluating 00053.png (response: 1) ...
# 0.3086726665496826
# ...
# 0.272458553314209
# evaluating 00060.png (response: 1) ...
# 0.27091407775878906
# evaluating 00061.png (response: 1) ...
# 0.32698702812194824
# evaluating 00062.png (response: 1) ...
# 0.2723255157470703
# evaluating 00063.png (response: 1) ...
# 0.27257561683654785
# evaluating 00064.png (response: 1) ...
# 0.30852580070495605
# evaluating 00065.png (response: 1) ...
# 0.2722046375274658
# evaluating 00066.png (response: 1) ...
# 0.3274266719818115
# evaluating 00067.png (response: 1) ...
# 0.32747387886047363
# evaluating 00068.png (response: 1) ...
# 0.2747325897216797
# evaluating 00069.png (response: 1) ...
# 0.27628350257873535
# evaluating 00070.png (response: 1) ...
# 0.27371740341186523
# evaluating 00071.png (response: 1) ...
# 0.2738761901855469
# evaluating 00072.png (response: 1) ...
# 0.28742313385009766
# evaluating 00073.png (response: 1) ...
# 0.2734377384185791
# evaluating 00074.png (response: 1) ...
# 0.27408742904663086
# evaluating 00075.png (response: 1) ...
# 0.5262250900268555
# evaluating 00076.png (response: 1) ...
# 0.27710413932800293
# evaluating 00077.png (response: 1) ...
# 0.27246642112731934
# evaluating 00078.png (response: 1) ...
# 0.2718024253845215
# evaluating 00079.png (response: 1) ...
# 0.27750325202941895
# evaluating 00080.png (response: 1) ...
# 0.27249622344970703
# evaluating 00081.png (response: 1) ...
# 0.2774479389190674
# evaluating 00082.png (response: 1) ...
# 0.27233052253723145
# evaluating 00083.png (response: 1) ...
# 0.273700475692749
# evaluating 00084.png (response: 1) ...
# 0.29902172088623047
# evaluating 00085.png (response: 1) ...
# 0.2737572193145752
# evaluating 00086.png (response: 1) ...
# 0.32712507247924805
# evaluating 00087.png (response: 1) ...
# 0.2733581066131592
# evaluating 00088.png (response: 1) ...
# 0.2996253967285156
# evaluating 00089.png (response: 1) ...
# 0.2714245319366455
# evaluating 00090.png (response: 1) ...
# 0.27190709114074707
# evaluating 00091.png (response: 1) ...
# 0.27384448051452637
# evaluating 00092.png (response: 1) ...
# 0.30701470375061035
# evaluating 00093.png (response: 1) ...
# 0.27242350578308105
# evaluating 00094.png (response: 1) ...
# 0.27266788482666016
# evaluating 00095.png (response: 1) ...
# 0.27223896980285645
# evaluating 00096.png (response: 1) ...
# 0.2802774906158447
# evaluating 00097.png (response: 1) ...
# 0.2733423709869385
# evaluating 00098.png (response: 1) ...
# 0.2995624542236328
# evaluating 00099.png (response: 1) ...
# 0.2713596820831299
# evaluating 00100.png (response: 1) ...
# 0.2980775833129883
# evaluating 00101.png (response: 1) ...
# 0.27432751655578613
# evaluating 00102.png (response: 1) ...
# 0.2741713523864746
# evaluating 00103.png (response: 1) ...
# 0.2729003429412842
# evaluating 00104.png (response: 1) ...
# 0.28553152084350586
# evaluating 00105.png (response: 1) ...
# 0.27298879623413086
# evaluating 00106.png (response: 1) ...
# 0.2876570224761963
# evaluating 00107.png (response: 1) ...
# 0.2752726078033447
# evaluating 00108.png (response: 1) ...
# 0.27570152282714844
# evaluating 00109.png (response: 1) ...
# 0.2744600772857666
# evaluating 00110.png (response: 1) ...
# 0.27183079719543457
# evaluating 00111.png (response: 1) ...
# 0.30948829650878906
# evaluating 00112.png (response: 1) ...
# 0.27382373809814453
# 308
# evaluating 00003.png (response: 0) ...
# 0.22961068153381348
# evaluating 00004.png (response: 1) ...
# 0.38080596923828125
# evaluating 00005.png (response: 1) ...
# 0.3424947261810303
# evaluating 00006.png (response: 1) ...
# 0.27374744415283203
# evaluating 00007.png (response: 1) ...
# 0.28838682174682617
# evaluating 00008.png (response: 1) ...
# 0.27431726455688477
# evaluating 00009.png (response: 1) ...
# 0.2961294651031494
# evaluating 00010.png (response: 1) ...
# 0.2728996276855469
# evaluating 00011.png (response: 1) ...
# 0.30190300941467285
# evaluating 00012.png (response: 1) ...
# 0.2727184295654297
# evaluating 00013.png (response: 1) ...
# 0.32128095626831055
# evaluating 00014.png (response: 1) ...
# 0.27282214164733887
# evaluating 00015.png (response: 1) ...
# 0.27960848808288574
# evaluating 00016.png (response: 1) ...
# 0.3297874927520752
# evaluating 00017.png (response: 1) ...
# 0.27367162704467773
# evaluating 00018.png (response: 1) ...
# 0.27591776847839355
# evaluating 00019.png (response: 1) ...
# 0.3058650493621826
# evaluating 00020.png (response: 1) ...
# 0.2738962173461914
# evaluating 00021.png (response: 1) ...
# 0.29686760902404785
# evaluating 00022.png (response: 1) ...
# 0.27268314361572266
# evaluating 00023.png (response: 1) ...
# 0.3012363910675049
# evaluating 00024.png (response: 1) ...
# 0.2729642391204834
# evaluating 00025.png (response: 1) ...
# 0.28048062324523926
# evaluating 00026.png (response: 1) ...
# 0.2727789878845215
# evaluating 00027.png (response: 1) ...
# 0.32753896713256836
# evaluating 00028.png (response: 1) ...
# 0.273759126663208
# evaluating 00029.png (response: 1) ...
# 0.30167174339294434
# evaluating 00030.png (response: 1) ...
# 0.27211880683898926
# evaluating 00031.png (response: 1) ...
# 0.2713661193847656
# evaluating 00032.png (response: 1) ...
# 0.29833292961120605
# evaluating 00033.png (response: 1) ...
# 0.27129268646240234
# evaluating 00034.png (response: 1) ...
# 0.29317808151245117
# evaluating 00035.png (response: 1) ...
# 0.2715122699737549
# evaluating 00036.png (response: 1) ...
# 0.3066105842590332
# evaluating 00037.png (response: 1) ...
# 0.2722342014312744
# evaluating 00038.png (response: 1) ...
# 0.27607107162475586
# evaluating 00039.png (response: 1) ...
# 0.3164088726043701
# evaluating 00040.png (response: 1) ...
# 0.2723426818847656
# evaluating 00041.png (response: 1) ...
# 0.2765786647796631
# evaluating 00042.png (response: 1) ...
# 0.5417664051055908
# evaluating 00043.png (response: 1) ...
# 0.27286720275878906
# evaluating 00044.png (response: 1) ...
# 0.27255725860595703
# evaluating 00045.png (response: 1) ...
# 0.28953003883361816
# evaluating 00046.png (response: 1) ...
# 0.2729058265686035
# evaluating 00047.png (response: 1) ...
# 0.2797548770904541
# evaluating 00048.png (response: 1) ...
# 0.3023202419281006
# evaluating 00049.png (response: 1) ...
# 0.27284765243530273
# evaluating 00050.png (response: 1) ...
# 0.31195521354675293
# evaluating 00051.png (response: 1) ...
# 0.27155232429504395
# evaluating 00052.png (response: 1) ...
# 0.27205824851989746
# evaluating 00053.png (response: 1) ...
# 0.3169229030609131
# evaluating 00054.png (response: 1) ...
# 0.27223682403564453
# evaluating 00055.png (response: 1) ...
# 0.31835031509399414
# evaluating 00056.png (response: 1) ...
# 0.27206945419311523
# evaluating 00057.png (response: 1) ...
# 0.2918062210083008
# evaluating 00058.png (response: 1) ...
# 0.27268266677856445
# evaluating 00059.png (response: 1) ...
# 0.31441593170166016
# evaluating 00060.png (response: 1) ...
# 0.27478456497192383
# evaluating 00061.png (response: 1) ...
# 0.3458230495452881
# evaluating 00062.png (response: 1) ...
# 0.2726900577545166
# evaluating 00063.png (response: 1) ...
# 0.29372072219848633
# evaluating 00064.png (response: 1) ...
# 0.27306342124938965
# evaluating 00065.png (response: 1) ...
# 0.30550551414489746
# evaluating 00066.png (response: 1) ...
# 0.2758183479309082
# evaluating 00067.png (response: 1) ...
# 0.27237820625305176
# evaluating 00068.png (response: 1) ...
# 0.3079559803009033
# evaluating 00069.png (response: 1) ...
# 0.2735564708709717
# evaluating 00070.png (response: 1) ...
# 0.2775712013244629
# evaluating 00071.png (response: 1) ...
# 0.29018497467041016
# evaluating 00072.png (response: 1) ...
# 0.27236294746398926
# evaluating 00073.png (response: 1) ...
# 0.2729310989379883
# evaluating 00074.png (response: 1) ...
# 0.2977886199951172
# evaluating 00075.png (response: 1) ...
# 0.272430419921875
# evaluating 00076.png (response: 1) ...
# 0.3049314022064209
# evaluating 00077.png (response: 1) ...
# 0.27232980728149414
# evaluating 00078.png (response: 1) ...
# 0.28870582580566406
# evaluating 00079.png (response: 1) ...
# 0.2726461887359619
# evaluating 00080.png (response: 1) ...
# 0.5629370212554932
# evaluating 00081.png (response: 1) ...
# 0.27307605743408203
# evaluating 00082.png (response: 1) ...
# 0.29145121574401855
# evaluating 00083.png (response: 1) ...
# 0.32224035263061523
# evaluating 00084.png (response: 1) ...
# 0.2737874984741211
# evaluating 00085.png (response: 1) ...
# 0.30173516273498535
# evaluating 00086.png (response: 1) ...
# 0.2781500816345215
# evaluating 00087.png (response: 1) ...
# 0.2731139659881592
# evaluating 00088.png (response: 1) ...
# 0.33219146728515625
# evaluating 00089.png (response: 1) ...
# 0.2723202705383301
# evaluating 00090.png (response: 1) ...
# 0.3005349636077881
# evaluating 00091.png (response: 1) ...
# 0.27132201194763184
# evaluating 00092.png (response: 1) ...
# 0.3050675392150879
# evaluating 00093.png (response: 1) ...
# 0.2719731330871582
# evaluating 00094.png (response: 1) ...
# 0.2838926315307617
# evaluating 00095.png (response: 1) ...
# 0.2723691463470459
# evaluating 00096.png (response: 1) ...
# 0.30890655517578125
# evaluating 00097.png (response: 1) ...
# 0.271761417388916
# evaluating 00098.png (response: 1) ...
# 0.2951774597167969
# evaluating 00099.png (response: 1) ...
# 0.2724936008453369
# evaluating 00100.png (response: 1) ...
# 0.32003355026245117
# evaluating 00101.png (response: 1) ...
# 0.27609682083129883
# evaluating 00102.png (response: 1) ...
# 0.27751898765563965
# evaluating 00103.png (response: 1) ...
# 0.2728133201599121
# evaluating 00104.png (response: 1) ...
# 0.27595019340515137
# evaluating 00105.png (response: 1) ...
# 0.28642868995666504
# evaluating 00106.png (response: 1) ...
# 0.2755012512207031
# evaluating 00107.png (response: 1) ...
# 0.31238889694213867
# evaluating 00108.png (response: 1) ...
# 0.27390456199645996
# evaluating 00109.png (response: 1) ...
# 0.2722024917602539
# evaluating 00110.png (response: 1) ...
# 0.27192211151123047
# evaluating 00111.png (response: 1) ...
# 0.30795812606811523
# evaluating 00112.png (response: 1) ...
# 0.27193212509155273
# 309
# evaluating 00003.png (response: 0) ...
# 0.2296457290649414
# evaluating 00004.png (response: 1) ...
# 0.31885361671447754
# evaluating 00005.png (response: 1) ...
# 0.3015880584716797
# evaluating 00006.png (response: 1) ...
# 0.2728304862976074
# evaluating 00007.png (response: 1) ...
# 0.2796797752380371
# evaluating 00008.png (response: 1) ...
# 0.2739286422729492
# evaluating 00009.png (response: 1) ...
# 0.2743704319000244
# evaluating 00010.png (response: 1) ...
# 0.2905547618865967
# evaluating 00011.png (response: 1) ...
# 0.27889060974121094
# evaluating 00012.png (response: 1) ...
# 0.3072068691253662
# evaluating 00013.png (response: 1) ...
# 0.27213215827941895
# evaluating 00014.png (response: 1) ...
# 0.3273894786834717
# evaluating 00015.png (response: 1) ...
# 0.27413296699523926
# evaluating 00016.png (response: 1) ...
# 0.2780778408050537
# evaluating 00017.png (response: 1) ...
# 0.31884002685546875
# evaluating 00018.png (response: 1) ...
# 0.2721598148345947
# evaluating 00019.png (response: 1) ...
# 0.3112354278564453
# evaluating 00020.png (response: 1) ...
# 0.4849226474761963
# evaluating 00021.png (response: 1) ...
# 0.2792067527770996
# evaluating 00022.png (response: 1) ...
# 0.3165717124938965
# evaluating 00023.png (response: 1) ...
# 0.2740139961242676
# evaluating 00024.png (response: 1) ...
# 0.31962156295776367
# evaluating 00025.png (response: 1) ...
# 0.275423526763916
# evaluating 00026.png (response: 1) ...
# 0.32831692695617676
# evaluating 00027.png (response: 1) ...
# 0.27416110038757324
# evaluating 00028.png (response: 1) ...
# 0.30927157402038574
# evaluating 00029.png (response: 1) ...
# 0.27333617210388184
# evaluating 00030.png (response: 1) ...
# 0.3048272132873535
# evaluating 00031.png (response: 1) ...
# 0.2748293876647949
# evaluating 00032.png (response: 1) ...
# 0.2724156379699707
# evaluating 00033.png (response: 1) ...
# 0.29505157470703125
# evaluating 00034.png (response: 1) ...
# 0.2733497619628906
# evaluating 00035.png (response: 1) ...
# 0.27556800842285156
# evaluating 00036.png (response: 1) ...
# 0.3180363178253174
# evaluating 00037.png (response: 1) ...
# 0.2728230953216553
# evaluating 00038.png (response: 1) ...
# 0.2723655700683594
# evaluating 00039.png (response: 1) ...
# 0.2747993469238281
# evaluating 00040.png (response: 1) ...
# 0.2735762596130371
# evaluating 00041.png (response: 1) ...
# 0.2736508846282959
# evaluating 00042.png (response: 1) ...
# 0.2742271423339844
# evaluating 00043.png (response: 1) ...
# 0.2762155532836914
# evaluating 00044.png (response: 1) ...
# 0.2805659770965576
# evaluating 00045.png (response: 1) ...
# 0.2739737033843994
# evaluating 00046.png (response: 1) ...
# 0.29093360900878906
# evaluating 00047.png (response: 1) ...
# 0.27254152297973633
# evaluating 00048.png (response: 1) ...
# 0.2828514575958252
# evaluating 00049.png (response: 1) ...
# 0.2788515090942383
# evaluating 00050.png (response: 1) ...
# 0.3353767395019531
# evaluating 00051.png (response: 1) ...
# 0.2747833728790283
# evaluating 00052.png (response: 1) ...
# 0.34029173851013184
# evaluating 00053.png (response: 1) ...
# 0.27391624450683594
# evaluating 00054.png (response: 1) ...
# 0.30324769020080566
# evaluating 00055.png (response: 1) ...
# 0.2760777473449707
# evaluating 00056.png (response: 1) ...
# 0.30448031425476074
# evaluating 00057.png (response: 1) ...
# 0.5063073635101318
# evaluating 00058.png (response: 1) ...
# 0.2726709842681885
# evaluating 00059.png (response: 1) ...
# 0.3114478588104248
# evaluating 00060.png (response: 1) ...
# 0.2745821475982666
# evaluating 00061.png (response: 1) ...
# 0.3082611560821533
# evaluating 00062.png (response: 1) ...
# 0.27513790130615234
# evaluating 00063.png (response: 1) ...
# 0.3078594207763672
# evaluating 00064.png (response: 1) ...
# 0.288649320602417
# evaluating 00065.png (response: 1) ...
# 0.27349066734313965
# evaluating 00066.png (response: 1) ...
# 0.32728147506713867
# evaluating 00067.png (response: 1) ...
# 0.3200819492340088
# evaluating 00068.png (response: 1) ...
# 0.27405810356140137
# evaluating 00069.png (response: 1) ...
# 0.3047676086425781
# evaluating 00070.png (response: 1) ...
# 0.274324893951416
# evaluating 00071.png (response: 1) ...
# 0.27518367767333984
# evaluating 00072.png (response: 1) ...
# 0.2965221405029297
# evaluating 00073.png (response: 1) ...
# 0.27355146408081055
# evaluating 00074.png (response: 1) ...
# 0.3073122501373291
# evaluating 00075.png (response: 1) ...
# 0.27445316314697266
# evaluating 00076.png (response: 1) ...
# 0.30559635162353516
# evaluating 00077.png (response: 1) ...
# 0.31322407722473145
# evaluating 00078.png (response: 1) ...
# 0.273273229598999
# evaluating 00079.png (response: 1) ...
# 0.3027806282043457
# evaluating 00080.png (response: 1) ...
# 0.2893640995025635
# evaluating 00081.png (response: 1) ...
# 0.27381443977355957
# evaluating 00082.png (response: 1) ...
# 0.32907629013061523
# evaluating 00083.png (response: 1) ...
# 0.2734837532043457
# evaluating 00084.png (response: 1) ...
# 0.35752296447753906
# evaluating 00085.png (response: 1) ...
# 0.31545186042785645
# evaluating 00086.png (response: 1) ...
# 0.27298879623413086
# evaluating 00087.png (response: 1) ...
# 0.3252239227294922
# evaluating 00088.png (response: 1) ...
# 0.27508997917175293
# evaluating 00089.png (response: 1) ...
# 0.2777853012084961
# evaluating 00090.png (response: 1) ...
# 0.32289886474609375
# evaluating 00091.png (response: 1) ...
# 0.27270936965942383
# evaluating 00092.png (response: 1) ...
# 0.3020589351654053
# evaluating 00093.png (response: 1) ...
# 0.2741658687591553
# evaluating 00094.png (response: 1) ...
# 0.5702934265136719
# evaluating 00095.png (response: 1) ...
# 0.27434730529785156
# evaluating 00096.png (response: 1) ...
# 0.32965612411499023
# evaluating 00097.png (response: 1) ...
# 0.27358460426330566
# evaluating 00098.png (response: 1) ...
# 0.32155585289001465
# evaluating 00099.png (response: 1) ...
# 0.2736387252807617
# evaluating 00100.png (response: 1) ...
# 0.2745993137359619
# evaluating 00101.png (response: 1) ...
# 0.2752082347869873
# evaluating 00102.png (response: 1) ...
# 0.3121790885925293
# evaluating 00103.png (response: 1) ...
# 0.27372264862060547
# evaluating 00104.png (response: 1) ...
# 0.2811112403869629
# evaluating 00105.png (response: 1) ...
# 0.29370832443237305
# evaluating 00106.png (response: 1) ...
# 0.2742760181427002
# evaluating 00107.png (response: 1) ...
# 0.2726595401763916
# evaluating 00108.png (response: 1) ...
# 0.29639410972595215
# evaluating 00109.png (response: 1) ...
# 0.2716796398162842
# evaluating 00110.png (response: 1) ...
# 0.272083044052124
# evaluating 00111.png (response: 1) ...
# 0.3016643524169922
# evaluating 00112.png (response: 1) ...
# 0.2747800350189209

# %%
sw = np.array(sw).reshape(len(breaks), -1)
hw = np.array(hw).reshape(len(breaks), -1) / (187.512 * 1000000)
assert sw.shape == hw.shape, (sw.shape, hw.shape)
print(sw.shape)
# Out:
# (12, 109)

# %%
print("overhead:", np.median(np.sum(hw - sw, axis=0) * 1000), "ms")
# Out:
# overhead: 4.606157996008698 ms
